# %% [markdown]
# # LazyFox Workflow
#
# This is a guide on how to use our LazyFox project. It downloads the [Eu-Core dataset from the SNAP Group](https://snap.stanford.edu/data/email-Eu-core.html) and runs the LazyFox algorithm on it.
#
# Further analysis can be made on the resulting output using the `Analysis.ipynb` notebook.
#
# Note that this notebook is only examplary and not fit to handle larger datasets. Use the code here or refer to the `README.md` to run LazyFox from the commandline.

# %% [markdown]
# ## Setup
#
# Fetch the latest release of LazyFox or compile it yourself and specify the path to the binary below!
#
# You can also change the directories used, they will be created if not already present.

# %%
lazy_fox_binary = "../LazyFox"

dataset_directory = "./datasets"
output_directory = "./output"

# %%
# Make the binary executable
# !chmod +x {lazy_fox_binary}

# %%
import os
import os.path
import urllib
import gzip
import shutil
import uuid

from Datasets import download


# Setup directories
os.makedirs(dataset_directory, exist_ok=True)

# Download the Eu-Core dataset
download("eu", dataset_directory)

# %% [markdown]
# ## Run
# The following cells build the command to run LazyFox.
#
# If the linux time utility exists (`/usr/bin/time`) the command is also benchmarked!

# %%
# Dataset input
eu_txt_path = os.path.join(dataset_directory, "email-Eu-core.txt")

# Create a unique run directory
run_output_directory = os.path.join(output_directory, uuid.uuid1().hex)
os.makedirs(run_output_directory, exist_ok=True)

queue_size = 1
thread_count = queue_size # highest parallelization degree possible is thread_count equal to queue_size
dumping = 1 # Whether computation results should be dumped to disk [0|1]

log_file = os.path.join(run_output_directory, "log")

command = f"{lazy_fox_binary} {eu_txt_path} {run_output_directory} {queue_size} {thread_count} {dumping}"
print("The raw command:")
print(command)
# Out:
# The raw command:
# ../LazyFox ./datasets/email-Eu-core.txt ./output/ec9ad1c814db11ec920c8900ab60aac0 1 1 1

# %%
# Capture the stdout and stderr into a log file
command = command + f" 2>&1 > {log_file}"
print("The command with log file capture:")
print(command)
# Out:
# The command with log file capture:
# ../LazyFox ./datasets/email-Eu-core.txt ./output/ec9ad1c814db11ec920c8900ab60aac0 1 1 1 2>&1 > ./output/ec9ad1c814db11ec920c8900ab60aac0/log

# %%
# Add time benchmark to the command
if os.path.exists("/usr/bin/time"):
    benchmark_file = os.path.join(run_output_directory, "bench.mark")
    benchmark_prefix = f"/usr/bin/time -v -o {benchmark_file}"

    command = f"{benchmark_prefix} {command}"
    
    print("Command with time benchmark:")
    print(command)
else:
    print("'/usr/bin/time' not found, running without benchmark!")
# Out:
# Command with time benchmark:
# /usr/bin/time -v -o ./output/ec9ad1c814db11ec920c8900ab60aac0/bench.mark ../LazyFox ./datasets/email-Eu-core.txt ./output/ec9ad1c814db11ec920c8900ab60aac0 1 1 1 2>&1 > ./output/ec9ad1c814db11ec920c8900ab60aac0/log

# %%
# Run the benchmark command in bash shell
# !{command}

# %%
# Display the log
# !cat {log_file}
# Out:
# Starting Fox
# running fox with input ./datasets/email-Eu-core.txt and output ./output/ec9ad1c814db11ec920c8900ab60aac0processing a queue size of 1 and working with 1 threads
# dumping is enabled
# loading input file
# finding max node id
# building the adj list
# building vectors from sets
# graph loaded
# running with 1 threads
# beginning initialisation
# counting neighbors
# calculating CC Per node
# done
# ordering notes
# computing CC Global
# CC Global: 0.399355
# initial clustering
# initial clustering produced 404 communities
# initial clustering maps
# finished the hashmap population
# global WCC
# initialization done
# cleaning broken communities
# starting the main loop
# 0.01 is the threshold
# Processing Chunk {  0.0%} [                                        ] (0.0s < infs) iteration 0 done
# numberStays 301
# numberLeaves 3
# numberCopies 677
# numberTransfers 24
# relative change1.49
# epoch took 0.0409717s
# dumping results...
# results dumped successfully
# Processing Chunk {  0.0%} [                                        ] (0.0s < infs) iteration 1 done
# numberStays 355
# numberLeaves 55
# numberCopies 535
# numberTransfers 60
# relative change0.588045
# epoch took 0.0749708s
# dumping results...
# results dumped successfully
# Processing Chunk {  0.0%} [                                        ] (0.0s < infs) iteration 2 done
# numberStays 450
# numberLeaves 65
# numberCopies 444
# numberTransfers 46
# relative change0.329582
# epoch took 0.116586s
# dumping results...
# results dumped successfully
# Processing Chunk { 85.4%} [##################################      ] (0.2s < 0.0s) iteration 3 done
# numberStays 503
# numberLeaves 65
# numberCopies 417
# numberTransfers 20
# relative change0.218823
# epoch took 0.160745s
# dumping results...
# results dumped successfully
# Processing Chunk { 75.0%} [##############################          ] (0.2s < 0.1s) iteration 4 done
# numberStays 573
# numberLeaves 53
# numberCopies 356
# numberTransfers 23
# relative change0.136564
# epoch took 0.210838s
# dumping results...
# results dumped successfully
# Processing Chunk { 66.3%} [###########################             ] (0.2s < 0.1s) iteration 5 done
# numberStays 615
# numberLeaves 48
# numberCopies 317
# numberTransfers 25
# relative change0.0968109
# epoch took 0.26158s
# dumping results...
# results dumped successfully
# Processing Chunk { 85.3%} [##################################      ] (0.3s < 0.1s) iteration 6 done
# numberStays 628
# numberLeaves 59
# numberCopies 291
# numberTransfers 27
# relative change0.074735
# epoch took 0.320617s
# dumping results...
# results dumped successfully
# Processing Chunk { 77.3%} [###############################         ] (0.3s < 0.1s) iteration 7 done
# numberStays 666
# numberLeaves 40
# numberCopies 274
# numberTransfers 25
# relative change0.0770214
# epoch took 0.37901s
# dumping results...
# results dumped successfully
# Processing Chunk { 72.0%} [#############################           ] (0.3s < 0.1s) iteration 8 done
# numberStays 680
# numberLeaves 52
# numberCopies 253
# numberTransfers 20
# relative change0.055454
# epoch took 0.42568s
# dumping results...
# results dumped successfully
# Processing Chunk { 84.9%} [##################################      ] (0.5s < 0.1s) iteration 9 done
# numberStays 704
# numberLeaves 31
# numberCopies 255
# numberTransfers 15
# relative change0.0483733
# epoch took 0.482486s
# dumping results...
# results dumped successfully
# Processing Chunk { 79.0%} [################################        ] (0.5s < 0.1s) iteration 10 done
# numberStays 771
# numberLeaves 42
# numberCopies 187
# numberTransfers 5
# relative change0.0321408
# epoch took 0.543357s
# dumping results...
# results dumped successfully
# Processing Chunk { 86.5%} [###################################     ] (0.6s < 0.1s) iteration 11 done
# numberStays 793
# numberLeaves 26
# numberCopies 175
# numberTransfers 11
# relative change0.0255762
# epoch took 0.621818s
# dumping results...
# results dumped successfully
# Processing Chunk { 83.8%} [##################################      ] (0.6s < 0.1s) iteration 12 done
# numberStays 789
# numberLeaves 25
# numberCopies 184
# numberTransfers 7
# relative change0.0249514
# epoch took 0.655593s
# dumping results...
# results dumped successfully
# Processing Chunk { 77.4%} [###############################         ] (0.6s < 0.2s) iteration 13 done
# numberStays 777
# numberLeaves 19
# numberCopies 195
# numberTransfers 14
# relative change0.0268795
# epoch took 0.735921s
# dumping results...
# results dumped successfully
# Processing Chunk { 93.2%} [#####################################   ] (0.8s < 0.1s) iteration 14 done
# numberStays 806
# numberLeaves 26
# numberCopies 164
# numberTransfers 9
# relative change0.0196401
# epoch took 0.759738s
# dumping results...
# results dumped successfully
# Processing Chunk { 84.4%} [##################################      ] (0.8s < 0.1s) iteration 15 done
# numberStays 811
# numberLeaves 26
# numberCopies 151
# numberTransfers 17
# relative change0.0201772
# epoch took 0.811171s
# dumping results...
# results dumped successfully
# Processing Chunk { 80.1%} [################################        ] (0.8s < 0.2s) iteration 16 done
# numberStays 861
# numberLeaves 17
# numberCopies 121
# numberTransfers 6
# relative change0.0128228
# epoch took 0.87453s
# dumping results...
# results dumped successfully
# Processing Chunk { 86.8%} [###################################     ] (0.9s < 0.1s) iteration 17 done
# numberStays 870
# numberLeaves 13
# numberCopies 119
# numberTransfers 3
# relative change0.010754
# epoch took 0.936085s
# dumping results...
# results dumped successfully
# Processing Chunk { 83.0%} [#################################       ] (0.9s < 0.2s) iteration 18 done
# numberStays 871
# numberLeaves 13
# numberCopies 119
# numberTransfers 2
# relative change0.0106305
# epoch took 0.997728s
# dumping results...
# results dumped successfully
# Processing Chunk { 95.1%} [######################################  ] (1.1s < 0.1s) iteration 19 done
# numberStays 883
# numberLeaves 13
# numberCopies 108
# numberTransfers 1
# relative change0.00964122
# epoch took 1.05956s
# dumping results...
# results dumped successfully
# postprocessing still due
# finished computation at Mon Sep 13 23:45:44 2021
# elapsed time: 10.5341s
